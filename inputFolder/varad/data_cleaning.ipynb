# %%
import pandas as pd 

#change this path in your system
base_folder = "D:/Projects/Food-AI/inputFolder/varad/"

raw_data = pd.read_csv(base_folder+"ingredients_raw_file_v1.csv")

raw_data.head()
# Out:
#                      id                  asins          brand  \
# 0  AVphBRHOilAPnD_x0OrE             B00HXST15C  Simon Fischer
# 1  AVpfNFy1LJeJML434ma2  B008VT0W8C,B0092F8OJ8      McCormick
# 2  AVpgT49VLJeJML43MJEz             B00CHTWZ2S     Jolly Time
# 3  AVphYgnzLJeJML43aPp2             B002JJYNVW          Ziyad
# 4  AVpiS0bOLJeJML43kRsh             B00290W1CY    Fla-Vor-Ice
#
#                             categories             dateAdded  \
# 0  Grocery & Gourmet Food,Food,Grocery  2017-01-07T20:13:17Z
# 1  Grocery & Gourmet Food,Food,Grocery  2016-02-05T21:08:01Z
# 2       Grocery & Gourmet Food,Grocery  2014-02-18T01:51:23Z
# 3       Grocery & Gourmet Food,grocery  2014-11-04T11:39:27Z
# 4       Grocery & Gourmet Food,grocery  2014-02-18T02:32:12Z
#
#             dateUpdated                              ean features.key  \
# 0  2017-06-30T16:48:02Z                      41642026706  Ingredients
# 1  2017-04-12T13:54:04Z                      52100018164  Ingredients
# ...

# %%
# List column names
column_names = raw_data.columns
print(column_names)
# Out:
# Index(['id', 'asins', 'brand', 'categories', 'dateAdded', 'dateUpdated', 'ean',
#        'features.key', 'features.value', 'manufacturer', 'manufacturerNumber',
#        'name', 'sizes', 'upc', 'weight', 'Unnamed: 15'],
#       dtype='object')

# %%
# extract only certain column names

filtered_data = raw_data[['brand','features.value']]

# %%
filtered_data = filtered_data.fillna('')
filtered_data
# Out:
#               brand                                     features.value
# 0     Simon Fischer        Dried Prunes,Water,Corn Syrup,Sugar,Pectin.
# 1         McCormick  Salt,Sugar,Molasses (Refinery Syrup, Molasses,...
# 2        Jolly Time  Salt, Yellow 5 Lake, Tricalcium Phosphate And ...
# 3             Ziyad  Mechanically hulled seasame seeds.Allergy Info...
# 4       Fla-Vor-Ice                                              FALSE
# ...             ...                                                ...
# 9995       Wright's                water,natural hickory smoke flavor.
# 9996     Eden Foods  Organic Dry Roasted Almonds,Organic Tamari Soy...
# 9997    Happy Belly  Cashews, Vegetable Oil (May Contain One Or Mor...
# 9998         Quaker  Whole Grain Brown Rice Flour,Degerminated Mill...
# 9999       Weetabix  Non-GMO Whole Grain Wheat,Non-GMO Whole Grain ...
#
# [10000 rows x 2 columns]

# %%
#Remove Unanamed column

data.drop(columns=['Unnamed: 15' , 'sizes'], inplace = True )

# %%
# Fill missing values for specific columns
data['asins'].fillna('Unknown', inplace=True)
data['brand'].fillna('Unknown', inplace=True)
data['ean'].fillna('Unknown', inplace=True)
data['manufacturer'].fillna('Unknown', inplace=True)
data['manufacturerNumber'].fillna('Unknown', inplace=True)
data['upc'].fillna('Unknown', inplace=True)
data['weight'].fillna('Unknown', inplace=True)

# %%
data.dropna(subset='name')
# Out:
#                         id                  asins          brand  \
# 0     AVphBRHOilAPnD_x0OrE             B00HXST15C  Simon Fischer
# 1     AVpfNFy1LJeJML434ma2  B008VT0W8C,B0092F8OJ8      McCormick
# 2     AVpgT49VLJeJML43MJEz             B00CHTWZ2S     Jolly Time
# 3     AVphYgnzLJeJML43aPp2             B002JJYNVW          Ziyad
# 4     AVpiS0bOLJeJML43kRsh             B00290W1CY    Fla-Vor-Ice
# ...                    ...                    ...            ...
# 9995  AVpfVL3ailAPnD_xZyHc  B00BHNV8N2,B06XC7GXCD       Wright's
# 9996  AVpgK5BZilAPnD_xofxu             B00HZO4YYW     Eden Foods
# 9997  AV00srHj-jtxr-f30m1M  B01FRJ0XKA,B01IV1D1VY    Happy Belly
# 9998  AVpfmY4RLJeJML43ANr-  B000PWIR7Q,B005ER1C6U         Quaker
# 9999  AVpe-j33LJeJML43zpy-             B001EO5JUC       Weetabix
#
#                                              categories             dateAdded  \
# 0                   Grocery & Gourmet Food,Food,Grocery  2017-01-07T20:13:17Z
# ...

# %%
data['dateAdded'] = pd.to_datetime(data['dateAdded'], errors = 'coerce')
data['dateUpdated'] = pd.to_datetime(data['dateUpdated'], errors = 'coerce')

# %%
data
# Out:
#                         id                  asins          brand  \
# 0     AVphBRHOilAPnD_x0OrE             B00HXST15C  Simon Fischer
# 1     AVpfNFy1LJeJML434ma2  B008VT0W8C,B0092F8OJ8      McCormick
# 2     AVpgT49VLJeJML43MJEz             B00CHTWZ2S     Jolly Time
# 3     AVphYgnzLJeJML43aPp2             B002JJYNVW          Ziyad
# 4     AVpiS0bOLJeJML43kRsh             B00290W1CY    Fla-Vor-Ice
# ...                    ...                    ...            ...
# 9995  AVpfVL3ailAPnD_xZyHc  B00BHNV8N2,B06XC7GXCD       Wright's
# 9996  AVpgK5BZilAPnD_xofxu             B00HZO4YYW     Eden Foods
# 9997  AV00srHj-jtxr-f30m1M  B01FRJ0XKA,B01IV1D1VY    Happy Belly
# 9998  AVpfmY4RLJeJML43ANr-  B000PWIR7Q,B005ER1C6U         Quaker
# 9999  AVpe-j33LJeJML43zpy-             B001EO5JUC       Weetabix
#
#                                              categories  \
# 0                   Grocery & Gourmet Food,Food,Grocery
# 1                   Grocery & Gourmet Food,Food,Grocery
# ...

# %%
data.drop_duplicates()
# Out:
#                         id                  asins          brand  \
# 0     AVphBRHOilAPnD_x0OrE             B00HXST15C  Simon Fischer
# 1     AVpfNFy1LJeJML434ma2  B008VT0W8C,B0092F8OJ8      McCormick
# 2     AVpgT49VLJeJML43MJEz             B00CHTWZ2S     Jolly Time
# 3     AVphYgnzLJeJML43aPp2             B002JJYNVW          Ziyad
# 4     AVpiS0bOLJeJML43kRsh             B00290W1CY    Fla-Vor-Ice
# ...                    ...                    ...            ...
# 9995  AVpfVL3ailAPnD_xZyHc  B00BHNV8N2,B06XC7GXCD       Wright's
# 9996  AVpgK5BZilAPnD_xofxu             B00HZO4YYW     Eden Foods
# 9997  AV00srHj-jtxr-f30m1M  B01FRJ0XKA,B01IV1D1VY    Happy Belly
# 9998  AVpfmY4RLJeJML43ANr-  B000PWIR7Q,B005ER1C6U         Quaker
# 9999  AVpe-j33LJeJML43zpy-             B001EO5JUC       Weetabix
#
#                                              categories  \
# 0                   Grocery & Gourmet Food,Food,Grocery
# 1                   Grocery & Gourmet Food,Food,Grocery
# ...

# %%
data = data.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
data
# Out:
#                         id                  asins          brand  \
# 0     AVphBRHOilAPnD_x0OrE             B00HXST15C  Simon Fischer
# 1     AVpfNFy1LJeJML434ma2  B008VT0W8C,B0092F8OJ8      McCormick
# 2     AVpgT49VLJeJML43MJEz             B00CHTWZ2S     Jolly Time
# 3     AVphYgnzLJeJML43aPp2             B002JJYNVW          Ziyad
# 4     AVpiS0bOLJeJML43kRsh             B00290W1CY    Fla-Vor-Ice
# ...                    ...                    ...            ...
# 9995  AVpfVL3ailAPnD_xZyHc  B00BHNV8N2,B06XC7GXCD       Wright's
# 9996  AVpgK5BZilAPnD_xofxu             B00HZO4YYW     Eden Foods
# 9997  AV00srHj-jtxr-f30m1M  B01FRJ0XKA,B01IV1D1VY    Happy Belly
# 9998  AVpfmY4RLJeJML43ANr-  B000PWIR7Q,B005ER1C6U         Quaker
# 9999  AVpe-j33LJeJML43zpy-             B001EO5JUC       Weetabix
#
#                                              categories  \
# 0                   Grocery & Gourmet Food,Food,Grocery
# 1                   Grocery & Gourmet Food,Food,Grocery
# ...

# %%
# Save the cleaned dataframe to a new CSV file
data.to_csv("C:\Practice\cleaned_ingredients.csv", index=False)
